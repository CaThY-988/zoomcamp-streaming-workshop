# %%
# See if can confirm all homework answers

# %%
import pandas as pd

url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-10.parquet"
columns = ['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance', 'tip_amount', 'total_amount']
df = pd.read_parquet(url, columns=columns)

# %%
# Q2 - infer time to load from number of rows and lag time
print(len(df) * 0.01)
# Out:
# 494.16

# %%
# Q3
count = (df["trip_distance"] > 5).sum()
print(count)
# Out:
# 8506
